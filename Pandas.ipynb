# %% [markdown]
# Pandas Library

# %% [markdown]
# pandas is used to cleaning,analyzing , manipulating and exploring data sets

# %% [markdown]
# pandas can clean messy data sets , and make them readable and relevant
# Releavant data is very important in data science

# %% [markdown]
# Advantage:-
#
#
# 1. fast and efficient
# 2. easy handling of missing data( reprsented as NAN ) in flosating point ass well as non floating data
# 3. data set merging and joining
# 4. size mutability : column can be inserted and deleted from data frame

# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes == 'float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[df.dtypes[df.dtypes== 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes== 'int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
df[['Ticket']].head()
# Out:
#              Ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %%
df[['Ticket']][4:16:1]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Ticket']][4:16:2]
# Out:
#        Ticket
# 4      373450
# 6       17463
# 8      347742
# 10    PP 9549
# 12  A/5. 2151
# 14     350406

# %%
df[['Ticket','Cabin']]
# Out:
#                Ticket Cabin
# 0           A/5 21171   NaN
# 1            PC 17599   C85
# 2    STON/O2. 3101282   NaN
# 3              113803  C123
# 4              373450   NaN
# ..                ...   ...
# 886            211536   NaN
# 887            112053   B42
# 888        W./C. 6607   NaN
# 889            111369  C148
# 890            370376   NaN
#
# [891 rows x 2 columns]

# %%
df[['Ticket','Cabin']][3:24]
# Out:
#        Ticket Cabin
# 3      113803  C123
# 4      373450   NaN
# 5      330877   NaN
# 6       17463   E46
# 7      349909   NaN
# 8      347742   NaN
# 9      237736   NaN
# 10    PP 9549    G6
# 11     113783  C103
# 12  A/5. 2151   NaN
# 13     347082   NaN
# 14     350406   NaN
# 15     248706   NaN
# 16     382652   NaN
# 17     244373   NaN
# 18     345763   NaN
# 19       2649   NaN
# 20     239865   NaN
# 21     248698   D56
# 22     330923   NaN
# 23     113788    A6

# %%
df[['Ticket','Cabin']][2:20:1]
# Out:
#               Ticket Cabin
# 2   STON/O2. 3101282   NaN
# 3             113803  C123
# 4             373450   NaN
# 5             330877   NaN
# 6              17463   E46
# 7             349909   NaN
# 8             347742   NaN
# 9             237736   NaN
# 10           PP 9549    G6
# 11            113783  C103
# 12         A/5. 2151   NaN
# 13            347082   NaN
# 14            350406   NaN
# 15            248706   NaN
# 16            382652   NaN
# 17            244373   NaN
# 18            345763   NaN
# 19              2649   NaN

# %%
df[['Ticket','Cabin']][2:30:2]
# Out:
#               Ticket Cabin
# 2   STON/O2. 3101282   NaN
# 4             373450   NaN
# 6              17463   E46
# 8             347742   NaN
# 10           PP 9549    G6
# 12         A/5. 2151   NaN
# 14            350406   NaN
# 16            382652   NaN
# 18            345763   NaN
# 20            239865   NaN
# 22            330923   NaN
# 24            349909   NaN
# 26              2631   NaN
# 28            330959   NaN

# %% [markdown]
# Creating new column in data set

# %%
df['new col']=0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['new col1']=2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Nitesh']=14

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# create column with your own location

# %%
df.insert(loc = 3, column = 'food',value=0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  food  \
# 0              1         0       3     0
# 1              2         1       1     0
# 2              3         1       3     0
# 3              4         1       1     0
# 4              5         0       3     0
# ..           ...       ...     ...   ...
# 886          887         0       2     0
# 887          888         1       1     0
# 888          889         0       3     0
# 889          890         1       1     0
# 890          891         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.insert(loc= 1,column= ' tools' , value ='oxygen cylinder')

# %%
df
# Out:
#      PassengerId            tools  Survived  Pclass  food  \
# 0              1  oxygen cylinder         0       3     0
# 1              2  oxygen cylinder         1       1     0
# 2              3  oxygen cylinder         1       3     0
# 3              4  oxygen cylinder         1       1     0
# 4              5  oxygen cylinder         0       3     0
# ..           ...              ...       ...     ...   ...
# 886          887  oxygen cylinder         0       2     0
# 887          888  oxygen cylinder         1       1     0
# 888          889  oxygen cylinder         0       3     0
# 889          890  oxygen cylinder         1       1     0
# 890          891  oxygen cylinder         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
a=df['Name'][0:10]

# %%
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
I = ['Nitesh','a2','a3','a4','a5','a6','a7','a8','a9','a10']

# %%
pd.Series(a,index=I)
# Out:
# Nitesh    NaN
# a2        NaN
# a3        NaN
# a4        NaN
# a5        NaN
# a6        NaN
# a7        NaN
# a8        NaN
# a9        NaN
# a10       NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a),index=I)
# Out:
# Nitesh                              Braund, Mr. Owen Harris
# a2        Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                   Heikkinen, Miss. Laina
# a4             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                                 Allen, Mr. William Henry
# a6                                         Moran, Mr. James
# a7                                  McCarthy, Mr. Timothy J
# a8                           Palsson, Master. Gosta Leonard
# a9        Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                     Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1= pd.Series([100,200,300,400,500],index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000],index = [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3= pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m3=pd.concat([m1,m2],axis=1)

# %%
m3
# Out:
#      0     1
# 1  100   600
# 2  200   700
# 3  300   800
# 4  400   900
# 5  500  1000

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
m1-m2
# Out:
# 1   -500
# 2   -500
# 3   -500
# 4   -500
# 5   -500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId            tools  Survived  Pclass  food  \
# 0            1  oxygen cylinder         0       3     0
# 1            2  oxygen cylinder         1       1     0
# 2            3  oxygen cylinder         1       3     0
# 3            4  oxygen cylinder         1       1     0
# 4            5  oxygen cylinder         0       3     0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new col  new col1  Nitesh
# 0      0         A/5 21171   7.2500   NaN        S        0         2      14
# ...

# %% [markdown]
# Delete the column

# %%
df.drop("new col",axis=1)# temporary delete
# Out:
#      PassengerId            tools  Survived  Pclass  food  \
# 0              1  oxygen cylinder         0       3     0
# 1              2  oxygen cylinder         1       1     0
# 2              3  oxygen cylinder         1       3     0
# 3              4  oxygen cylinder         1       1     0
# 4              5  oxygen cylinder         0       3     0
# ..           ...              ...       ...     ...   ...
# 886          887  oxygen cylinder         0       2     0
# 887          888  oxygen cylinder         1       1     0
# 888          889  oxygen cylinder         0       3     0
# 889          890  oxygen cylinder         1       1     0
# 890          891  oxygen cylinder         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df
# Out:
#      PassengerId            tools  Survived  Pclass  food  \
# 0              1  oxygen cylinder         0       3     0
# 1              2  oxygen cylinder         1       1     0
# 2              3  oxygen cylinder         1       3     0
# 3              4  oxygen cylinder         1       1     0
# 4              5  oxygen cylinder         0       3     0
# ..           ...              ...       ...     ...   ...
# 886          887  oxygen cylinder         0       2     0
# 887          888  oxygen cylinder         1       1     0
# 888          889  oxygen cylinder         0       3     0
# 889          890  oxygen cylinder         1       1     0
# 890          891  oxygen cylinder         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.drop("Nitesh",axis =1 )
# Out:
#      PassengerId            tools  Survived  Pclass  food  \
# 0              1  oxygen cylinder         0       3     0
# 1              2  oxygen cylinder         1       1     0
# 2              3  oxygen cylinder         1       3     0
# 3              4  oxygen cylinder         1       1     0
# 4              5  oxygen cylinder         0       3     0
# ..           ...              ...       ...     ...   ...
# 886          887  oxygen cylinder         0       2     0
# 887          888  oxygen cylinder         1       1     0
# 888          889  oxygen cylinder         0       3     0
# 889          890  oxygen cylinder         1       1     0
# 890          891  oxygen cylinder         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
#permanent delete of column

df.drop("Survived",axis=1,inplace = True)

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 2              3  oxygen cylinder       3     0
# 3              4  oxygen cylinder       1     0
# 4              5  oxygen cylinder       3     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 2              3  oxygen cylinder       3     0
# 3              4  oxygen cylinder       1     0
# 4              5  oxygen cylinder       3     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# Deleting the rows

# %%
df.drop(2)# temporary
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# 6              7  oxygen cylinder       1     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ...

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 2              3  oxygen cylinder       3     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#for permanent deleting of rows
df.drop(2,inplace=True)

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 2              3  oxygen cylinder       3     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 2              3  oxygen cylinder       3     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# we make the column index

# %%
df.set_index('Name')#temporary change
# Out:
#                                                     PassengerId  \
# Name
# Braund, Mr. Owen Harris                                       1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2
# Allen, Mr. William Henry                                      5
# Moran, Mr. James                                              6
# McCarthy, Mr. Timothy J                                       7
# ...                                                         ...
# Montvila, Rev. Juozas                                       887
# Graham, Miss. Margaret Edith                                888
# Johnston, Miss. Catherine Helen "Carrie"                    889
# Behr, Mr. Karl Howell                                       890
# Dooley, Mr. Patrick                                         891
#
#                                                               tools  Pclass  \
# Name
# Braund, Mr. Owen Harris                             oxygen cylinder       3
# ...

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# 6              7  oxygen cylinder       1     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ...

# %%
df
# Out:
#      PassengerId            tools  Pclass  food  \
# 0              1  oxygen cylinder       3     0
# 1              2  oxygen cylinder       1     0
# 4              5  oxygen cylinder       3     0
# 5              6  oxygen cylinder       3     0
# 6              7  oxygen cylinder       1     0
# ..           ...              ...     ...   ...
# 886          887  oxygen cylinder       2     0
# 887          888  oxygen cylinder       1     0
# 888          889  oxygen cylinder       3     0
# 889          890  oxygen cylinder       1     0
# 890          891  oxygen cylinder       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ...

# %%
# for permanent we use inplace = True

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     PassengerId  \
# Name
# Braund, Mr. Owen Harris                                       1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2
# Allen, Mr. William Henry                                      5
# Moran, Mr. James                                              6
# McCarthy, Mr. Timothy J                                       7
# ...                                                         ...
# Montvila, Rev. Juozas                                       887
# Graham, Miss. Margaret Edith                                888
# Johnston, Miss. Catherine Helen "Carrie"                    889
# Behr, Mr. Karl Howell                                       890
# Dooley, Mr. Patrick                                         891
#
#                                                               tools  Pclass  \
# Name
# Braund, Mr. Owen Harris                             oxygen cylinder       3
# ...

# %% [markdown]
# Reset the Index

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  \
# 0                              Braund, Mr. Owen Harris            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2                             Allen, Mr. William Henry            5
# 3                                     Moran, Mr. James            6
# 4                              McCarthy, Mr. Timothy J            7
# ..                                                 ...          ...
# 884                              Montvila, Rev. Juozas          887
# 885                       Graham, Miss. Margaret Edith          888
# 886           Johnston, Miss. Catherine Helen "Carrie"          889
# 887                              Behr, Mr. Karl Howell          890
# 888                                Dooley, Mr. Patrick          891
#
#                tools  Pclass  food     Sex   Age  SibSp  Parch      Ticket  \
# ...

# %% [markdown]
# we make the dataframe through dictionary

# %%
d= {"key 1":[1,2,3,4,5],
   "key 2":[6,7,8,9,10],
   "key 3":[11,12,13,14,15]}

# %%
d
# Out:
# {'key 1': [1, 2, 3, 4, 5],
#  'key 2': [6, 7, 8, 9, 10],
#  'key 3': [11, 12, 13, 14, 15]}

# %%
dic = pd.DataFrame(d)

# %%
dic
# Out:
#    key 1  key 2  key 3
# 0      1      6     11
# 1      2      7     12
# 2      3      8     13
# 3      4      9     14
# 4      5     10     15

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#      Topic ID                                          Topic  Unnamed: 2
# 0           1                   Introduction and Linguistics         NaN
# 1           2             Language Modeling, Syntax, Parsing         NaN
# 2           3                            Semantics and Logic         NaN
# 3           4  Pragmatics, Discourse, Dialogue, Applications         NaN
# 4           5                                 Classification         NaN
# ..        ...                                            ...         ...
# 315       958                Computational Psycholinguistics         NaN
# 316       959                          Social Media Analysis         NaN
# 317       961                           Stuctured Prediction         NaN
# 318       999                                         Others         NaN
# 319     10000                    Natural Language Processing         NaN
#
# [320 rows x 3 columns]

# %% [markdown]
# for deleting the NAN value in data set

# %%
df1.dropna()#temporary changes
# Out:
# Empty DataFrame
# Columns: [Topic ID, Topic, Unnamed: 2]
# Index: []

# %%
df.dropna()
# Out:
#                                                     PassengerId  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2
# McCarthy, Mr. Timothy J                                       7
# Sandstrom, Miss. Marguerite Rut                              11
# Bonnell, Miss. Elizabeth                                     12
# Beesley, Mr. Lawrence                                        22
# ...                                                         ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872
# Carlsson, Mr. Frans Olof                                    873
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880
# Graham, Miss. Margaret Edith                                888
# Behr, Mr. Karl Howell                                       890
#
#                                                               tools  Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  oxygen cylinder       1
# ...

# %%
df
# Out:
#                                                     PassengerId  \
# Name
# Braund, Mr. Owen Harris                                       1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2
# Allen, Mr. William Henry                                      5
# Moran, Mr. James                                              6
# McCarthy, Mr. Timothy J                                       7
# ...                                                         ...
# Montvila, Rev. Juozas                                       887
# Graham, Miss. Margaret Edith                                888
# Johnston, Miss. Catherine Helen "Carrie"                    889
# Behr, Mr. Karl Howell                                       890
# Dooley, Mr. Patrick                                         891
#
#                                                               tools  Pclass  \
# Name
# Braund, Mr. Owen Harris                             oxygen cylinder       3
# ...

# %%
# for permanent delete NAN
df.dropna(inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.read_csv("titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# for deleting column NAN

df2.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# Replace the missing value by any things by yourself
df2.fillna("Nitesh")#temporary change
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 2                               Heikkinen, Miss. Laina  female    26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 4                             Allen, Mr. William Henry    male    35.0      0
# ...

# %%
# permanent change
df2.fillna("Nitesh", inplace = True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex     Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0      1
# 2                               Heikkinen, Miss. Laina  female    26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0      1
# 4                             Allen, Mr. William Henry    male    35.0      0
# ...
